# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('../content/sample_data/image/Tom&jerry.jpg')
print(image)
# Out:
# [[[13 17 75]
#   [12 16 74]
#   [12 16 75]
#   ...
#   [12 12 82]
#   [14 15 83]
#   [15 17 82]]
#
#  [[ 7 11 70]
#   [ 7 11 70]
#   [ 7 11 70]
#   ...
#   [ 9  9 79]
#   [10 11 79]
#   [11 13 78]]
#
#  [[ 7 10 71]
#   [ 7 10 71]
#   [ 7  9 73]
#   ...
#   [ 5  7 78]
#   [ 8  8 78]
#   [ 9 10 78]]
#
#  ...
#
#  [[25 25 25]
#   [ 0  0  0]
#   [ 3  3  3]
#   ...
#   [ 0  0  0]
#   [ 2  2  2]
#   [31 31 31]]
#
#  [[25 25 25]
#   [ 0  0  0]
#   [ 3  3  3]
#   ...
#   [ 0  0  0]
#   [ 2  2  2]
#   [31 31 31]]
#
#  [[25 25 25]
#   [ 0  0  0]
#   [ 3  3  3]
#   ...
#   [ 0  0  0]
#   [ 2  2  2]
#   [31 31 31]]]

# %%
print(image.shape)
# Out:
# (171, 294, 3)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.title('Gray image')
plt.imshow(gray_image)

plt.subplot(1,2,2)
plt.title('Grayed image')
plt.imshow(image)
plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.title('Gray image')
plt.imshow(cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB))

plt.subplot(1,2,2)
plt.title('Grayed image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
image = cv2.imread('../content/sample_data/image/Tom&jerry.jpg')
zeros=np.zeros((image.shape[0],image.shape[1]),np.uint8)
b,g,r=cv2.split(image)
print('Blue ',b)
print('Green',g)
print('Blue ',r)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
#gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#cv2_imshow(image)
#cv2_imshow(gray_image)
#plt.show()
cv2.waitKey(0)
# Out:
# Blue  [[13 12 12 ... 12 14 15]
#  [ 7  7  7 ...  9 10 11]
#  [ 7  7  7 ...  5  8  9]
#  ...
#  [25  0  3 ...  0  2 31]
#  [25  0  3 ...  0  2 31]
#  [25  0  3 ...  0  2 31]]
# Green [[17 16 16 ... 12 15 17]
#  [11 11 11 ...  9 11 13]
#  [10 10  9 ...  7  8 10]
#  ...
#  [25  0  3 ...  0  2 31]
#  [25  0  3 ...  0  2 31]
#  [25  0  3 ...  0  2 31]]
# Blue  [[75 74 75 ... 82 83 82]
#  [70 70 70 ... 79 79 78]
#  [71 71 73 ... 78 78 78]
#  ...
#  [25  0  3 ...  0  2 31]
#  [25  0  3 ...  0  2 31]
#  [25  0  3 ...  0  2 31]]
# <PIL.Image.Image image mode=L size=294x171 at 0x7F3CC1521BD0>
# <PIL.Image.Image image mode=L size=294x171 at 0x7F3CC15218D0>
# <PIL.Image.Image image mode=L size=294x171 at 0x7F3CC1521210>
# -1

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
#cap = cv2.VideoCapture('video.mp4')
cap = cv2.VideoCapture(0)
while cap.isOpened():
  success, frame=cap.read()
  if succes:
    gray_frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2_imshow(gray_frame)
    cv2_imshow(frame)
    k=cv2.waitkey(50)
    if k & 0xff == ord('q'):
      break
  else:
    break

  cap.release()
  cv2.destroyAllWindows()
